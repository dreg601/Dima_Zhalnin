# %% [markdown]
# <a href="https://colab.research.google.com/github/dreg601/test_task_inno/blob/main/Test_task_inno.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Предварительная подготовка

# %%
import pandas as pd
import io
import random
import matplotlib.pyplot as plt
import numpy as np 
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# Добавление всех библиотек, которые возможно понядобятся для работы.

# %%
df_main = pd.read_excel('test_task_inno.xlsx', sheet_name='Выгрузка')
df_main
# Out:
#            Фамилия        Имя      Отчество Дата рождения           Роль  \
# 0          Ходырев  Абдурагим    Викторович    1989-01-19  Преподаватель
# 1         Прохоров   Абуталиб    Леонидович    1961-06-03  Преподаватель
# 2         Емантаев       Аида     Сергеевич    1952-04-23  Преподаватель
# 3         Тарасова     Айгуль   Геннадиевна    1975-09-02       Методист
# 4       Кондрашова       Айша    Талгатовна    1963-12-16  Преподаватель
# ...            ...        ...           ...           ...            ...
# 1745       Грошева        Яна   Анатольевна    1979-06-01  Преподаватель
# 1746  Богославцева        Яна    Леонидовна    1977-07-14  Преподаватель
# 1747      Соколова        Яна    Михайловна    1971-04-09  Преподаватель
# 1748        Звезда        Яна    Николаевна    1979-09-05  Преподаватель
# 1749      Курочкин    Ярослав  Вячеславович    1991-07-22  Преподаватель
#
#                             Образовательная организация  \
# 0                                      ВИПЭ ФСИН РОССИИ
# 1     ДОНСКОЙ ГОСУДАРСТВЕННЫЙ ТЕХНИЧЕСКИЙ УНИВЕРСИТЕ...
# 2     КНИТУ-КАИ,ФГБОУ ВО "КНИТУ-КАИ",КАЗАНСКИЙ НАЦИО...
# 3     ФГБОУ ВО &quot;ТАМБОВСКИЙ ГОСУДАРСТВЕННЫЙ УНИВ...
# 4               ФГБОУ ВО КАЗАНСКИЙ ГМУ МИНЗДРАВА РОССИИ
# ...                                                 ...
# 1745  ФГАОУ ВО "СЕВАСТОПОЛЬСКИЙ ГОСУДАРСТВЕННЫЙ УНИВ...
# 1746  ГАПОУ АО "АСТРАХАНСКИЙ КОЛЛЕДЖ АРТ-ФЭШН ИНДУСТ...
# 1747                                   ФГБОУ ВО "КНИТУ"
# 1748                             ФГБОУ ВО "НГУЭУ",НГУЭУ
# 1749  ЗЕЛЕНОДОЛЬСКИЙ ИНСТИТУТ МАШИНОСТРОЕНИЯ И ИНФОР...
#
#      Укрупненные группы направлений подготовки/ФГОС 3++/Отрасль  Балл за тест
# 0     44.00.00 Образование и педагогические науки / ...                  0.84
# 1     44.00.00 Образование и педагогические науки / ...                  0.68
# 2     02.00.00 Компьютерные и информационные науки /...                  0.72
# 3     38.00.00 Экономика и управление  / 38.02.06 Фи...                  0.63
# 4     10.00.00 Информационная безопасность / 10.05.0...                  0.76
# ...                                                 ...                   ...
# 1745  38.00.00 Экономика и управление  / 38.03.01 Эк...                  1.00
# 1746  31.00.00 Клиническая медицина / 31.02.05 Стома...                  0.72
# 1747  44.00.00 Образование и педагогические науки / ...                  0.76
# 1748  10.00.00 Информационная безопасность / 10.03.0...                  0.74
# 1749  38.00.00 Экономика и управление  / 38.03.04 Го...                  0.75
#
# [1750 rows x 8 columns]

# %%
df_route = pd.read_excel('test_task_inno.xlsx', sheet_name='Отрасли-Направления')
df_route
# Out:
#                           Отрасль Направление
# 0             Городское хозяйство         ООЦ
# 1       Добывающая промышленность         ООЦ
# 2                 Здравоохранение         ООЦ
# 3                             ИКТ         ЕМЦ
# 4   Обрабатывающая промышленность         ООЦ
# 5                     Образование         ООЦ
# 6              Сельское хозяйство         ООЦ
# 7                   Строительство         ООЦ
# 8     Транспортная инфраструктура         ООЦ
# 9               Финансовые услуги         ООЦ
# 10  Энергетическая инфраструктура         ООЦ
# 11             Общественные науки         ООЦ

# %%
df_moder = pd.read_excel('test_task_inno.xlsx', sheet_name='Модераторы')
df_moder
# Out:
#                              ФИО  \
# 0          Иванов Петр Сергеевич
# 1        Миронова Дарья Олеговна
# 2   Самсонова Татьяна Алекссевна
# 3      Ильин Александр Романович
# 4     Куликова Марина Леонидовна
# 5   Феоктистова Раяна Зиннуровна
# 6        Краева Олеся Васильевна
# 7   Насибуллин Альберт Маратович
# 8       Гришин Василий Сергеевич
# 9   Хакимуллина Гузель Сабировна
# 10       Новик Алексей Федорович
# 11     Шакиров Анвар Исмагилович
#
#                              Предпочтительная отрасль
# 0                  ИКТ, Обрабатывающая промышленность
# 1          Обрабатывающая промышленность, Образование
# 2                        Образование, Здравоохранение
# 3                     Сельское хозяйство, Образование
# 4                                  Строительство, ИКТ
# 5   Транспортная инфраструктура, Добывающая промыш...
# 6                              Финансовые услуги, ИКТ
# 7          Энергетическая инфраструктура, Образование
# 8   Общественные науки, Городское хозяйство, Финан...
# 9              Городское хозяйство, Финансовые услуги
# 10             Добывающая промышленность, Образование
# 11                                    Здравоохранение

# %% [markdown]
# Создание дата-фреймов и предварительный просмотр. Как можно посмотреть, во 2 и 3 таблице все заполнено, но 1 таблица слишком большая.

# %% [markdown]
# Первый пункт. Проверка дата-фреймов

# %%
df_main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1750 entries, 0 to 1749
# Data columns (total 8 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   Фамилия                                                     1750 non-null   object
#  1   Имя                                                         1750 non-null   object
#  2   Отчество                                                    1745 non-null   object
#  3   Дата рождения                                               1747 non-null   datetime64[ns]
#  4   Роль                                                        1747 non-null   object
#  5   Образовательная организация                                 1748 non-null   object
#  6   Укрупненные группы направлений подготовки/ФГОС 3++/Отрасль  1741 non-null   object
#  7   Балл за тест                                                1750 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(6)
# memory usage: 109.5+ KB

# %%
df_main_fi = df_main['Фамилия'] + ' ' + df_main['Имя']
df_main_fi.nunique()
# Out:
# 1713

# %%
df_main_fi[df_main_fi.duplicated()]
# Out:
# 66           Шихов Александр
# 126            Левин Алексей
# 240          Негадаев Андрей
# 256          Курбанов Андрей
# 434         Захаров Владимир
# 628         Попова Екатерина
# 632      Кузнецова Екатерина
# 647       Комарова Екатерина
# 654      Кузнецова Екатерина
# 686          Платонова Елена
# 687           Тимошина Елена
# 688          Шаплыгина Елена
# 707           Андреева Елена
# 711           Воротнюк Елена
# 721         Григорьева Елена
# 723          Соловьева Елена
# 763            Акулова Елена
# 821            Убушаев Игорь
# 873             Мосина Ирина
# 883          Курманова Ирина
# 985          Голянова Любовь
# 1068         Федченко Марина
# 1070      Духовникова Марина
# 1169          Кетова Наталия
# 1219         Ярыгина Наталья
# 1245          Попова Наталья
# 1253        Киселева Наталья
# 1347        Петровская Ольга
# 1444            Щербак Роман
# 1552          Сафонов Сергей
# 1562       Ахметзянов Сергей
# 1605         Евсеева Татьяна
# 1619        Матвеева Татьяна
# 1647      Терентьева Татьяна
# 1653        Смирнова Татьяна
# 1657    Селиверстова Татьяна
# 1722           Логинова Юлия
# dtype: object

# %% [markdown]
# Неуникальных наборов Имя + Фамилия меньше чем строк в датафрейме. Значит, есть дубликаты. Можно посмотреть на наличие недостающих данных.

# %%
df_main_match = df_main[(df_main.Отчество.isnull())]
df_main_match
# Out:
#           Фамилия      Имя Отчество Дата рождения           Роль  \
# 1083     Логинова   Марина      NaN    1978-10-03  Преподаватель
# 1254     Матвеева  Наталья      NaN    1983-04-21  Преподаватель
# 1411  Пустовалова    Ольга      NaN    1990-09-26  Преподаватель
# 1449      Сафаров    Роман      NaN    1977-05-15  Преподаватель
# 1577     Вотякова   Тамара      NaN    1993-01-27  Преподаватель
#
#                             Образовательная организация  \
# 1083  ФГБОУ ВО "ДАГЕСТАНСКИЙ ГОСУДАРСТВЕННЫЙ УНИВЕРС...
# 1254  МОСКОВСКИЙ ПОЛИТЕХНИЧЕСКИЙ УНИВЕРСИТЕТ, МОСКОВ...
# 1411  СПБГУПТД ФГБОУ ВО "САНКТ-ПЕТЕРБУРГСКИЙ ГОСУДАР...
# 1449  ЧИСТОПОЛЬСКИЙ ФИЛИАЛ "ВОСТОК" ФЕДЕРАЛЬНОГО ГОС...
# 1577                                ФГБОУ ВО "НИУ "МЭИ"
#
#      Укрупненные группы направлений подготовки/ФГОС 3++/Отрасль  Балл за тест
# 1083  09.00.00 Информатика и вычислительная техника ...                  0.89
# 1254  11.00.00 Электроника, радиотехника и системы с...                  0.64
# 1411  09.00.00 Информатика и вычислительная техника ...                  0.81
# 1449  09.00.00 Информатика и вычислительная техника ...                  0.77
# 1577  27.00.00 Управление в технических системах  / ...                  0.69

# %%
df_main[(df_main['Дата рождения'].isnull())]
# Out:
#        Фамилия        Имя   Отчество Дата рождения           Роль  \
# 97     Сергеев    Алексей  Борисович           NaT  Преподаватель
# 201  Балханова  Анастасия   Петровна           NaT  Преподаватель
# 283     Сатина       Анна   Игоревна           NaT       Методист
#
#                            Образовательная организация  \
# 97   КНИТУ-КАИ,ФГБОУ ВО "КНИТУ-КАИ",КАЗАНСКИЙ НАЦИО...
# 201  САМАРСКИЙ ГОСУДАРСТВЕННЫЙ СОЦИАЛЬНО-ПЕДАГОГИЧЕ...
# 283                                     ГАПОУ ТО "АТК"
#
#     Укрупненные группы направлений подготовки/ФГОС 3++/Отрасль  Балл за тест
# 97   22.00.00 Технологии материалов / 22.03.02 Мета...                  0.84
# 201  38.00.00 Экономика и управление  / 38.03.02 Ме...                  0.78
# 283  38.00.00 Экономика и управление  / 38.03.01 Эк...                  0.87

# %%
df_main[(df_main.Роль.isnull())]
# Out:
#         Фамилия      Имя      Отчество Дата рождения Роль  \
# 1456   Дубенчук   Рустем  Владимирович    1990-04-24  NaN
# 1615  Курьянова  Татьяна  Владимировна    1965-12-02  NaN
# 1742     Еремин     Яков   Анатольевич    1982-03-25  NaN
#
#          Образовательная организация  \
# 1456                 ФГБОУ ВО "АГТУ"
# 1615       ФГБОУ ВО ВОЛОГОДСКАЯ ГМХА
# 1742  РОССИЙСКАЯ ТАМОЖЕННАЯ АКАДЕМИЯ
#
#      Укрупненные группы направлений подготовки/ФГОС 3++/Отрасль  Балл за тест
# 1456  13.00.00 Электро- и теплоэнергетика / 13.02.06...                  0.83
# 1615  09.00.00 Информатика и вычислительная техника ...                  0.75
# 1742  10.00.00 Информационная безопасность / 10.03.0...                  0.81

# %%
df_main[(df_main['Образовательная организация'].isnull())]
# Out:
#        Фамилия       Имя    Отчество Дата рождения           Роль  \
# 424   Гурьянов  Владимир  Аркадьевич    1984-07-10  Преподаватель
# 485  Барсукова    Галина   Сергеевна    1975-12-02  Преподаватель
#
#     Образовательная организация  \
# 424                         NaN
# 485                         NaN
#
#     Укрупненные группы направлений подготовки/ФГОС 3++/Отрасль  Балл за тест
# 424  23.00.00 Техника и технологии наземного трансп...                  0.74
# 485  11.00.00 Электроника, радиотехника и системы с...                  0.05

# %%
df_main[(df_main['Укрупненные группы направлений подготовки/ФГОС 3++/Отрасль'].isnull())]
# Out:
#           Фамилия        Имя      Отчество Дата рождения           Роль  \
# 205     Сидорская  Анастасия     Сергеевна    1990-06-01  Преподаватель
# 623    Машковцева  Екатерина    Аркадьевна    1985-09-07  Преподаватель
# 641      Тарасова  Екатерина    Евгеньевна    1971-04-01  Преподаватель
# 704   Головастова      Елена  Владимировна    1954-03-26       Методист
# 989        Савина     Любовь    Николаевна    1981-07-03  Преподаватель
# 1301    Медянкина     Оксана    Николаевна    1983-10-29  Преподаватель
# 1369   Григоренко      Ольга  Вячеславовна    1982-09-13  Преподаватель
# 1379      Кутьева      Ольга      Игоревна    1990-11-15  Преподаватель
# 1382       Амаева      Ольга    Михайловна    1983-09-18  Преподаватель
#
#                             Образовательная организация  \
# 205       ОРЕНБУРГСКИЙ ГОСУДАРСТВЕННЫЙ УНИВЕРСИТЕТ, ОГУ
# 623                                               МТУСИ
# 641   НГГТИ, ГАОУ ВО "НЕВИННОМЫССКИЙ ГОСУДАРСТВЕННЫЙ...
# 704            ФГБОУ ВО РГАУ-МСХА ИМЕНИ К.А. ТИМИРЯЗЕВА
# 989   ФГБОУ ВО "РЭУ ИМ. Г.В. ПЛЕХАНОВА", РЭУ ИМ. Г.В...
# 1301  ФГБОУ ВО "РЭУ ИМ. Г.В. ПЛЕХАНОВА", РЭУ ИМ. Г.В...
# 1369  ФГБОУ ВО "АЛТАЙСКИЙ ГОСУДАРСТВЕННЫЙ УНИВЕРСИТЕ...
# 1379                            ФГБОУ ВО "РГГМУ", РГГМУ
# 1382  ФГБОУ ВО "ИГУ", ИГУ, ИРКУТСКИЙ ГОСУДАРСТВЕННЫЙ...
#
#      Укрупненные группы направлений подготовки/ФГОС 3++/Отрасль  Балл за тест
# 205                                                 NaN                  0.82
# 623                                                 NaN                  0.77
# 641                                                 NaN                  0.81
# 704                                                 NaN                  0.69
# 989                                                 NaN                  0.88
# 1301                                                NaN                  0.59
# 1369                                                NaN                  0.84
# 1379                                                NaN                  0.75
# 1382                                                NaN                  0.81

# %% [markdown]
# Итог первого пункта. Во-первых, в строках есть нулевые значения. Во-вторых, в столбце образовательная организация обнаружены &quot значения. Это аналог кавычек.

# %% [markdown]
# Второй пункт задания

# %%
def loc(df_main):
  df_main.dropna(subset=['Отчество'], inplace=True)
  df_main.loc[df_main['Отчество'].str.endswith('вич'), 'Пол'] = 'М'
  df_main.loc[df_main['Отчество'].str.endswith('вна'), 'Пол'] = 'Ж'
  return df_main
loc(df_main)
df_main
# Out:
#            Фамилия        Имя      Отчество Дата рождения           Роль  \
# 0          Ходырев  Абдурагим    Викторович    1989-01-19  Преподаватель
# 1         Прохоров   Абуталиб    Леонидович    1961-06-03  Преподаватель
# 2         Емантаев       Аида     Сергеевич    1952-04-23  Преподаватель
# 3         Тарасова     Айгуль   Геннадиевна    1975-09-02       Методист
# 4       Кондрашова       Айша    Талгатовна    1963-12-16  Преподаватель
# ...            ...        ...           ...           ...            ...
# 1745       Грошева        Яна   Анатольевна    1979-06-01  Преподаватель
# 1746  Богославцева        Яна    Леонидовна    1977-07-14  Преподаватель
# 1747      Соколова        Яна    Михайловна    1971-04-09  Преподаватель
# 1748        Звезда        Яна    Николаевна    1979-09-05  Преподаватель
# 1749      Курочкин    Ярослав  Вячеславович    1991-07-22  Преподаватель
#
#                             Образовательная организация  \
# 0                                      ВИПЭ ФСИН РОССИИ
# 1     ДОНСКОЙ ГОСУДАРСТВЕННЫЙ ТЕХНИЧЕСКИЙ УНИВЕРСИТЕ...
# 2     КНИТУ-КАИ,ФГБОУ ВО "КНИТУ-КАИ",КАЗАНСКИЙ НАЦИО...
# 3     ФГБОУ ВО &quot;ТАМБОВСКИЙ ГОСУДАРСТВЕННЫЙ УНИВ...
# 4               ФГБОУ ВО КАЗАНСКИЙ ГМУ МИНЗДРАВА РОССИИ
# ...                                                 ...
# 1745  ФГАОУ ВО "СЕВАСТОПОЛЬСКИЙ ГОСУДАРСТВЕННЫЙ УНИВ...
# 1746  ГАПОУ АО "АСТРАХАНСКИЙ КОЛЛЕДЖ АРТ-ФЭШН ИНДУСТ...
# 1747                                   ФГБОУ ВО "КНИТУ"
# 1748                             ФГБОУ ВО "НГУЭУ",НГУЭУ
# 1749  ЗЕЛЕНОДОЛЬСКИЙ ИНСТИТУТ МАШИНОСТРОЕНИЯ И ИНФОР...
#
#      Укрупненные группы направлений подготовки/ФГОС 3++/Отрасль  Балл за тест  \
# 0     44.00.00 Образование и педагогические науки / ...                  0.84
# 1     44.00.00 Образование и педагогические науки / ...                  0.68
# 2     02.00.00 Компьютерные и информационные науки /...                  0.72
# 3     38.00.00 Экономика и управление  / 38.02.06 Фи...                  0.63
# 4     10.00.00 Информационная безопасность / 10.05.0...                  0.76
# ...                                                 ...                   ...
# 1745  38.00.00 Экономика и управление  / 38.03.01 Эк...                  1.00
# 1746  31.00.00 Клиническая медицина / 31.02.05 Стома...                  0.72
# 1747  44.00.00 Образование и педагогические науки / ...                  0.76
# 1748  10.00.00 Информационная безопасность / 10.03.0...                  0.74
# 1749  38.00.00 Экономика и управление  / 38.03.04 Го...                  0.75
#
#      Пол  Полных лет
# 0      М          33
# 1      М          61
# 2      М          70
# 3      Ж          47
# 4      Ж          58
# ...   ..         ...
# 1745   Ж          43
# 1746   Ж          45
# 1747   Ж          51
# 1748   Ж          43
# 1749   М          31
#
# [1745 rows x 10 columns]

# %%
df_main["Полных лет"] = \
    (pd.to_datetime("today") - df_main["Дата рождения"]).astype('<m8[Y]')
df_main.round()
# Out:
#            Фамилия        Имя      Отчество Дата рождения           Роль  \
# 0          Ходырев  Абдурагим    Викторович    1989-01-19  Преподаватель
# 1         Прохоров   Абуталиб    Леонидович    1961-06-03  Преподаватель
# 2         Емантаев       Аида     Сергеевич    1952-04-23  Преподаватель
# 3         Тарасова     Айгуль   Геннадиевна    1975-09-02       Методист
# 4       Кондрашова       Айша    Талгатовна    1963-12-16  Преподаватель
# ...            ...        ...           ...           ...            ...
# 1745       Грошева        Яна   Анатольевна    1979-06-01  Преподаватель
# 1746  Богославцева        Яна    Леонидовна    1977-07-14  Преподаватель
# 1747      Соколова        Яна    Михайловна    1971-04-09  Преподаватель
# 1748        Звезда        Яна    Николаевна    1979-09-05  Преподаватель
# 1749      Курочкин    Ярослав  Вячеславович    1991-07-22  Преподаватель
#
#                             Образовательная организация  \
# 0                                      ВИПЭ ФСИН РОССИИ
# 1     ДОНСКОЙ ГОСУДАРСТВЕННЫЙ ТЕХНИЧЕСКИЙ УНИВЕРСИТЕ...
# 2     КНИТУ-КАИ,ФГБОУ ВО "КНИТУ-КАИ",КАЗАНСКИЙ НАЦИО...
# 3     ФГБОУ ВО &quot;ТАМБОВСКИЙ ГОСУДАРСТВЕННЫЙ УНИВ...
# 4               ФГБОУ ВО КАЗАНСКИЙ ГМУ МИНЗДРАВА РОССИИ
# ...                                                 ...
# 1745  ФГАОУ ВО "СЕВАСТОПОЛЬСКИЙ ГОСУДАРСТВЕННЫЙ УНИВ...
# 1746  ГАПОУ АО "АСТРАХАНСКИЙ КОЛЛЕДЖ АРТ-ФЭШН ИНДУСТ...
# 1747                                   ФГБОУ ВО "КНИТУ"
# 1748                             ФГБОУ ВО "НГУЭУ",НГУЭУ
# 1749  ЗЕЛЕНОДОЛЬСКИЙ ИНСТИТУТ МАШИНОСТРОЕНИЯ И ИНФОР...
#
#      Укрупненные группы направлений подготовки/ФГОС 3++/Отрасль  Балл за тест  \
# 0     44.00.00 Образование и педагогические науки / ...                   1.0
# 1     44.00.00 Образование и педагогические науки / ...                   1.0
# 2     02.00.00 Компьютерные и информационные науки /...                   1.0
# 3     38.00.00 Экономика и управление  / 38.02.06 Фи...                   1.0
# 4     10.00.00 Информационная безопасность / 10.05.0...                   1.0
# ...                                                 ...                   ...
# 1745  38.00.00 Экономика и управление  / 38.03.01 Эк...                   1.0
# 1746  31.00.00 Клиническая медицина / 31.02.05 Стома...                   1.0
# 1747  44.00.00 Образование и педагогические науки / ...                   1.0
# 1748  10.00.00 Информационная безопасность / 10.03.0...                   1.0
# 1749  38.00.00 Экономика и управление  / 38.03.04 Го...                   1.0
#
#      Пол  Полных лет
# 0      М        33.0
# 1      М        61.0
# 2      М        70.0
# 3      Ж        47.0
# 4      Ж        58.0
# ...   ..         ...
# 1745   Ж        43.0
# 1746   Ж        45.0
# 1747   Ж        51.0
# 1748   Ж        43.0
# 1749   М        31.0
#
# [1745 rows x 10 columns]

# %%
df_main['Полных лет'] = df_main['Полных лет'].astype("Int64")
df_main
# Out:
#            Фамилия        Имя      Отчество Дата рождения           Роль  \
# 0          Ходырев  Абдурагим    Викторович    1989-01-19  Преподаватель
# 1         Прохоров   Абуталиб    Леонидович    1961-06-03  Преподаватель
# 2         Емантаев       Аида     Сергеевич    1952-04-23  Преподаватель
# 3         Тарасова     Айгуль   Геннадиевна    1975-09-02       Методист
# 4       Кондрашова       Айша    Талгатовна    1963-12-16  Преподаватель
# ...            ...        ...           ...           ...            ...
# 1745       Грошева        Яна   Анатольевна    1979-06-01  Преподаватель
# 1746  Богославцева        Яна    Леонидовна    1977-07-14  Преподаватель
# 1747      Соколова        Яна    Михайловна    1971-04-09  Преподаватель
# 1748        Звезда        Яна    Николаевна    1979-09-05  Преподаватель
# 1749      Курочкин    Ярослав  Вячеславович    1991-07-22  Преподаватель
#
#                             Образовательная организация  \
# 0                                      ВИПЭ ФСИН РОССИИ
# 1     ДОНСКОЙ ГОСУДАРСТВЕННЫЙ ТЕХНИЧЕСКИЙ УНИВЕРСИТЕ...
# 2     КНИТУ-КАИ,ФГБОУ ВО "КНИТУ-КАИ",КАЗАНСКИЙ НАЦИО...
# 3     ФГБОУ ВО &quot;ТАМБОВСКИЙ ГОСУДАРСТВЕННЫЙ УНИВ...
# 4               ФГБОУ ВО КАЗАНСКИЙ ГМУ МИНЗДРАВА РОССИИ
# ...                                                 ...
# 1745  ФГАОУ ВО "СЕВАСТОПОЛЬСКИЙ ГОСУДАРСТВЕННЫЙ УНИВ...
# 1746  ГАПОУ АО "АСТРАХАНСКИЙ КОЛЛЕДЖ АРТ-ФЭШН ИНДУСТ...
# 1747                                   ФГБОУ ВО "КНИТУ"
# 1748                             ФГБОУ ВО "НГУЭУ",НГУЭУ
# 1749  ЗЕЛЕНОДОЛЬСКИЙ ИНСТИТУТ МАШИНОСТРОЕНИЯ И ИНФОР...
#
#      Укрупненные группы направлений подготовки/ФГОС 3++/Отрасль  Балл за тест  \
# 0     44.00.00 Образование и педагогические науки / ...                  0.84
# 1     44.00.00 Образование и педагогические науки / ...                  0.68
# 2     02.00.00 Компьютерные и информационные науки /...                  0.72
# 3     38.00.00 Экономика и управление  / 38.02.06 Фи...                  0.63
# 4     10.00.00 Информационная безопасность / 10.05.0...                  0.76
# ...                                                 ...                   ...
# 1745  38.00.00 Экономика и управление  / 38.03.01 Эк...                  1.00
# 1746  31.00.00 Клиническая медицина / 31.02.05 Стома...                  0.72
# 1747  44.00.00 Образование и педагогические науки / ...                  0.76
# 1748  10.00.00 Информационная безопасность / 10.03.0...                  0.74
# 1749  38.00.00 Экономика и управление  / 38.03.04 Го...                  0.75
#
#      Пол  Полных лет
# 0      М          33
# 1      М          61
# 2      М          70
# 3      Ж          47
# 4      Ж          58
# ...   ..         ...
# 1745   Ж          43
# 1746   Ж          45
# 1747   Ж          51
# 1748   Ж          43
# 1749   М          31
#
# [1745 rows x 10 columns]

# %%
df_main[df_main.Пол =='Ж'].count()
# Out:
# Фамилия                                                       1144
# Имя                                                           1144
# Отчество                                                      1144
# Дата рождения                                                 1142
# Роль                                                          1143
# Образовательная организация                                   1143
# Укрупненные группы направлений подготовки/ФГОС 3++/Отрасль    1135
# Балл за тест                                                  1144
# Пол                                                           1144
# Полных лет                                                    1142
# dtype: int64

# %%
df_main[df_main.Пол =='М'].count()
# Out:
# Фамилия                                                       586
# Имя                                                           586
# Отчество                                                      586
# Дата рождения                                                 585
# Роль                                                          584
# Образовательная организация                                   585
# Укрупненные группы направлений подготовки/ФГОС 3++/Отрасль    586
# Балл за тест                                                  586
# Пол                                                           586
# Полных лет                                                    585
# dtype: int64

# %% [markdown]
# Как можно заметить, лиц женского пола в два раза больше, чем лиц мужского.

# %% [markdown]
# Третий пункт

# %%
def loc(df_main):
  df_main.dropna(subset=['Укрупненные группы направлений подготовки/ФГОС 3++/Отрасль'], inplace=True)
  df_main.loc[df_main['Укрупненные группы направлений подготовки/ФГОС 3++/Отрасль'].str.contains('/ Городское хозяйство'), 'Отрасль'] = 'Городское хозяйство'
  df_main.loc[df_main['Укрупненные группы направлений подготовки/ФГОС 3++/Отрасль'].str.contains('/ Добывающая промышленность'), 'Отрасль'] = 'Добывающая промышленность'
  df_main.loc[df_main['Укрупненные группы направлений подготовки/ФГОС 3++/Отрасль'].str.contains('/ Здравоохранение'), 'Отрасль'] = 'Здравоохранение'
  df_main.loc[df_main['Укрупненные группы направлений подготовки/ФГОС 3++/Отрасль'].str.contains('/ ИКТ'), 'Отрасль'] = 'ИКТ'
  df_main.loc[df_main['Укрупненные группы направлений подготовки/ФГОС 3++/Отрасль'].str.contains('/ Обрабатывающая промышленность'), 'Отрасль'] = 'Обрабатывающая промышленность'
  df_main.loc[df_main['Укрупненные группы направлений подготовки/ФГОС 3++/Отрасль'].str.contains('/ Образование'), 'Отрасль'] = 'Образование'
  df_main.loc[df_main['Укрупненные группы направлений подготовки/ФГОС 3++/Отрасль'].str.contains('/ Сельское хозяйство'), 'Отрасль'] = 'Сельское хозяйство'
  df_main.loc[df_main['Укрупненные группы направлений подготовки/ФГОС 3++/Отрасль'].str.contains('/ Строительство'), 'Отрасль'] = 'Строительство'
  df_main.loc[df_main['Укрупненные группы направлений подготовки/ФГОС 3++/Отрасль'].str.contains('/ Транспортная инфраструктура'), 'Отрасль'] = 'Транспортная инфраструктура'
  df_main.loc[df_main['Укрупненные группы направлений подготовки/ФГОС 3++/Отрасль'].str.contains('/ Финансовые услуги'), 'Отрасль'] = 'Финансовые услуги'
  df_main.loc[df_main['Укрупненные группы направлений подготовки/ФГОС 3++/Отрасль'].str.contains('/ Энергетическая инфраструктура'), 'Отрасль'] = 'Энергетическая инфраструктура'
  df_main.loc[df_main['Укрупненные группы направлений подготовки/ФГОС 3++/Отрасль'].str.contains('/ Общественные науки'), 'Отрасль'] = 'Общественные науки'  
  return df_main
loc(df_main)
df_main
# Out:
#            Фамилия        Имя      Отчество Дата рождения           Роль  \
# 0          Ходырев  Абдурагим    Викторович    1989-01-19  Преподаватель
# 1         Прохоров   Абуталиб    Леонидович    1961-06-03  Преподаватель
# 2         Емантаев       Аида     Сергеевич    1952-04-23  Преподаватель
# 3         Тарасова     Айгуль   Геннадиевна    1975-09-02       Методист
# 4       Кондрашова       Айша    Талгатовна    1963-12-16  Преподаватель
# ...            ...        ...           ...           ...            ...
# 1745       Грошева        Яна   Анатольевна    1979-06-01  Преподаватель
# 1746  Богославцева        Яна    Леонидовна    1977-07-14  Преподаватель
# 1747      Соколова        Яна    Михайловна    1971-04-09  Преподаватель
# 1748        Звезда        Яна    Николаевна    1979-09-05  Преподаватель
# 1749      Курочкин    Ярослав  Вячеславович    1991-07-22  Преподаватель
#
#                             Образовательная организация  \
# 0                                      ВИПЭ ФСИН РОССИИ
# 1     ДОНСКОЙ ГОСУДАРСТВЕННЫЙ ТЕХНИЧЕСКИЙ УНИВЕРСИТЕ...
# 2     КНИТУ-КАИ,ФГБОУ ВО "КНИТУ-КАИ",КАЗАНСКИЙ НАЦИО...
# 3     ФГБОУ ВО &quot;ТАМБОВСКИЙ ГОСУДАРСТВЕННЫЙ УНИВ...
# 4               ФГБОУ ВО КАЗАНСКИЙ ГМУ МИНЗДРАВА РОССИИ
# ...                                                 ...
# 1745  ФГАОУ ВО "СЕВАСТОПОЛЬСКИЙ ГОСУДАРСТВЕННЫЙ УНИВ...
# 1746  ГАПОУ АО "АСТРАХАНСКИЙ КОЛЛЕДЖ АРТ-ФЭШН ИНДУСТ...
# 1747                                   ФГБОУ ВО "КНИТУ"
# 1748                             ФГБОУ ВО "НГУЭУ",НГУЭУ
# 1749  ЗЕЛЕНОДОЛЬСКИЙ ИНСТИТУТ МАШИНОСТРОЕНИЯ И ИНФОР...
#
#      Укрупненные группы направлений подготовки/ФГОС 3++/Отрасль  Балл за тест  \
# 0     44.00.00 Образование и педагогические науки / ...                  0.84
# 1     44.00.00 Образование и педагогические науки / ...                  0.68
# 2     02.00.00 Компьютерные и информационные науки /...                  0.72
# 3     38.00.00 Экономика и управление  / 38.02.06 Фи...                  0.63
# 4     10.00.00 Информационная безопасность / 10.05.0...                  0.76
# ...                                                 ...                   ...
# 1745  38.00.00 Экономика и управление  / 38.03.01 Эк...                  1.00
# 1746  31.00.00 Клиническая медицина / 31.02.05 Стома...                  0.72
# 1747  44.00.00 Образование и педагогические науки / ...                  0.76
# 1748  10.00.00 Информационная безопасность / 10.03.0...                  0.74
# 1749  38.00.00 Экономика и управление  / 38.03.04 Го...                  0.75
#
#      Пол  Полных лет              Отрасль
# 0      М          33          Образование
# 1      М          61          Образование
# 2      М          70                  ИКТ
# 3      Ж          47    Финансовые услуги
# 4      Ж          58                  ИКТ
# ...   ..         ...                  ...
# 1745   Ж          43    Финансовые услуги
# 1746   Ж          45      Здравоохранение
# 1747   Ж          51          Образование
# 1748   Ж          43                  ИКТ
# 1749   М          31  Городское хозяйство
#
# [1736 rows x 11 columns]

# %%
df_main.merge(df_route)
# Out:
#          Фамилия        Имя       Отчество Дата рождения           Роль  \
# 0        Ходырев  Абдурагим     Викторович    1989-01-19  Преподаватель
# 1       Прохоров   Абуталиб     Леонидович    1961-06-03  Преподаватель
# 2      Сайфуллин  Александр  Александрович    1994-04-21  Преподаватель
# 3     Нестеренко  Александр  Александрович    1963-03-10       Методист
# 4        Василец  Александр     Васильевич    1975-05-08  Преподаватель
# ...          ...        ...            ...           ...            ...
# 1731   Купряшкин     Сергей   Владимирович    1987-06-16  Преподаватель
# 1732    Агронина     Тамара    Анатольевна    1952-10-12  Преподаватель
# 1733    Андреева       Юлия   Вячеславовна    1974-04-21  Преподаватель
# 1734      Жаркая       Юлия      Сергеевна    1984-07-30  Преподаватель
# 1735    Васильев       Юрий     Георгиевич    1982-09-16  Преподаватель
#
#                             Образовательная организация  \
# 0                                      ВИПЭ ФСИН РОССИИ
# 1     ДОНСКОЙ ГОСУДАРСТВЕННЫЙ ТЕХНИЧЕСКИЙ УНИВЕРСИТЕ...
# 2                                       ВЮИ ФСИН РОССИИ
# 3     ТУСУР, ФГБОУ ВО "ТУСУР", ФГБОУ ВО "ТОМСКИЙ ГОС...
# 4     КНИТУ-КАИ,ФГБОУ ВО "КНИТУ-КАИ",КАЗАНСКИЙ НАЦИО...
# ...                                                 ...
# 1731  САМАРСКИЙ ФИНАНСОВО-ЭКОНОМИЧЕСКИЙ КОЛЛЕДЖ - ФИ...
# 1732     ИРНИТУ, ФГБОУ ВО "ИРНИТУ", "ИРКУТСКИЙ ПОЛИТЕХ"
# 1733  ИНСТИТУТ НЕФТИ И ТЕХНОЛОГИЙ (ФИЛИАЛ) ФЕДЕРАЛЬН...
# 1734  ФГБОУ ВО "ПГУ", ПЕНЗЕНСКИЙ ГОСУДАРСТВЕННЫЙ УНИ...
# 1735  КНИТУ-КАИ,ФГБОУ ВО "КНИТУ-КАИ",КАЗАНСКИЙ НАЦИО...
#
#      Укрупненные группы направлений подготовки/ФГОС 3++/Отрасль  Балл за тест  \
# 0     44.00.00 Образование и педагогические науки / ...                  0.84
# 1     44.00.00 Образование и педагогические науки / ...                  0.68
# 2     44.00.00 Образование и педагогические науки / ...                  0.70
# 3     44.00.00 Образование и педагогические науки / ...                  0.67
# 4     44.00.00 Образование и педагогические науки / ...                  0.78
# ...                                                 ...                   ...
# 1731  13.00.00 Электро- и теплоэнергетика / 13.03.01...                  0.75
# 1732  13.00.00 Электро- и теплоэнергетика / 13.03.02...                  0.82
# 1733  13.00.00 Электро- и теплоэнергетика / 13.03.03...                  0.83
# 1734  13.00.00 Электро- и теплоэнергетика / 13.04.02...                  0.74
# 1735  13.00.00 Электро- и теплоэнергетика / 13.03.02...                  0.88
#
#      Пол  Полных лет                        Отрасль Направление
# 0      М          33                    Образование         ООЦ
# 1      М          61                    Образование         ООЦ
# 2      М          28                    Образование         ООЦ
# 3      М          59                    Образование         ООЦ
# 4      М          47                    Образование         ООЦ
# ...   ..         ...                            ...         ...
# 1731   М          35  Энергетическая инфраструктура         ООЦ
# 1732   Ж          70  Энергетическая инфраструктура         ООЦ
# 1733   Ж          48  Энергетическая инфраструктура         ООЦ
# 1734   Ж          38  Энергетическая инфраструктура         ООЦ
# 1735   М          40  Энергетическая инфраструктура         ООЦ
#
# [1736 rows x 12 columns]

# %% [markdown]
# Тут необходимо было просто смержить таблицы

# %% [markdown]
# Четвертый пункт

# %%
df_main.groupby(by = ['Отрасль'])['Фамилия'].count().plot(kind = 'bar', grid= True)

# %% [markdown]
# Это можно и к 5 отнести. Наибольшее количество студентов обучаются в ИКТ отрасли.

# %%
d = df_moder.set_index('ФИО').T.to_dict('dict')
random.choice(list(d.values()))
# Out:
# {'Предпочтительная отрасль': 'ИКТ, Обрабатывающая промышленность'}

# %%
def loc(df_main):
  df_main.loc[df_main['Отрасль'].str.contains('Городское хозяйство'), 'ФИО модера'] = random.choice(list(d.keys()))
  df_main.loc[df_main['Отрасль'].str.contains('Добывающая промышленность'), 'ФИО модера'] = random.choice(list(d.keys()))
  df_main.loc[df_main['Отрасль'].str.contains('Здравоохранение'), 'ФИО модера'] = random.choice(list(d.keys()))
  df_main.loc[df_main['Отрасль'].str.contains('ИКТ'), 'ФИО модера'] = random.choice(list(d.keys()))
  df_main.loc[df_main['Отрасль'].str.contains('Обрабатывающая промышленность'), 'ФИО модера'] = random.choice(list(d.keys()))
  df_main.loc[df_main['Отрасль'].str.contains('Образование'), 'ФИО модера'] = random.choice(list(d.keys()))
  df_main.loc[df_main['Отрасль'].str.contains('Сельское хозяйство'), 'ФИО модера'] = random.choice(list(d.keys()))
  df_main.loc[df_main['Отрасль'].str.contains('Строительство'), 'ФИО модера'] = random.choice(list(d.keys())) 
  df_main.loc[df_main['Отрасль'].str.contains('Транспортная инфраструктура'), 'ФИО модера'] = random.choice(list(d.keys()))
  df_main.loc[df_main['Отрасль'].str.contains('Финансовые услуги'), 'ФИО модера'] = random.choice(list(d.keys()))
  df_main.loc[df_main['Отрасль'].str.contains('Энергетическая инфраструктура'), 'ФИО модера'] = random.choice(list(d.keys()))
  df_main.loc[df_main['Отрасль'].str.contains('Общественные науки'), 'ФИО модера'] = random.choice(list(d.keys())) 
  return df_main

for i in range(len(df_main)):
  loc(df_main)
df_main
# Out:
#            Фамилия        Имя      Отчество Дата рождения           Роль  \
# 0          Ходырев  Абдурагим    Викторович    1989-01-19  Преподаватель
# 1         Прохоров   Абуталиб    Леонидович    1961-06-03  Преподаватель
# 2         Емантаев       Аида     Сергеевич    1952-04-23  Преподаватель
# 3         Тарасова     Айгуль   Геннадиевна    1975-09-02       Методист
# 4       Кондрашова       Айша    Талгатовна    1963-12-16  Преподаватель
# ...            ...        ...           ...           ...            ...
# 1745       Грошева        Яна   Анатольевна    1979-06-01  Преподаватель
# 1746  Богославцева        Яна    Леонидовна    1977-07-14  Преподаватель
# 1747      Соколова        Яна    Михайловна    1971-04-09  Преподаватель
# 1748        Звезда        Яна    Николаевна    1979-09-05  Преподаватель
# 1749      Курочкин    Ярослав  Вячеславович    1991-07-22  Преподаватель
#
#                             Образовательная организация  \
# 0                                      ВИПЭ ФСИН РОССИИ
# 1     ДОНСКОЙ ГОСУДАРСТВЕННЫЙ ТЕХНИЧЕСКИЙ УНИВЕРСИТЕ...
# 2     КНИТУ-КАИ,ФГБОУ ВО "КНИТУ-КАИ",КАЗАНСКИЙ НАЦИО...
# 3     ФГБОУ ВО &quot;ТАМБОВСКИЙ ГОСУДАРСТВЕННЫЙ УНИВ...
# 4               ФГБОУ ВО КАЗАНСКИЙ ГМУ МИНЗДРАВА РОССИИ
# ...                                                 ...
# 1745  ФГАОУ ВО "СЕВАСТОПОЛЬСКИЙ ГОСУДАРСТВЕННЫЙ УНИВ...
# 1746  ГАПОУ АО "АСТРАХАНСКИЙ КОЛЛЕДЖ АРТ-ФЭШН ИНДУСТ...
# 1747                                   ФГБОУ ВО "КНИТУ"
# 1748                             ФГБОУ ВО "НГУЭУ",НГУЭУ
# 1749  ЗЕЛЕНОДОЛЬСКИЙ ИНСТИТУТ МАШИНОСТРОЕНИЯ И ИНФОР...
#
#      Укрупненные группы направлений подготовки/ФГОС 3++/Отрасль  Балл за тест  \
# 0     44.00.00 Образование и педагогические науки / ...                  0.84
# 1     44.00.00 Образование и педагогические науки / ...                  0.68
# 2     02.00.00 Компьютерные и информационные науки /...                  0.72
# 3     38.00.00 Экономика и управление  / 38.02.06 Фи...                  0.63
# 4     10.00.00 Информационная безопасность / 10.05.0...                  0.76
# ...                                                 ...                   ...
# 1745  38.00.00 Экономика и управление  / 38.03.01 Эк...                  1.00
# 1746  31.00.00 Клиническая медицина / 31.02.05 Стома...                  0.72
# 1747  44.00.00 Образование и педагогические науки / ...                  0.76
# 1748  10.00.00 Информационная безопасность / 10.03.0...                  0.74
# 1749  38.00.00 Экономика и управление  / 38.03.04 Го...                  0.75
#
#      Пол  Полных лет              Отрасль                    ФИО модера
# 0      М          33          Образование      Гришин Василий Сергеевич
# 1      М          61          Образование      Гришин Василий Сергеевич
# 2      М          70                  ИКТ     Ильин Александр Романович
# 3      Ж          47    Финансовые услуги  Феоктистова Раяна Зиннуровна
# 4      Ж          58                  ИКТ     Ильин Александр Романович
# ...   ..         ...                  ...                           ...
# 1745   Ж          43    Финансовые услуги  Феоктистова Раяна Зиннуровна
# 1746   Ж          45      Здравоохранение       Новик Алексей Федорович
# 1747   Ж          51          Образование      Гришин Василий Сергеевич
# 1748   Ж          43                  ИКТ     Ильин Александр Романович
# 1749   М          31  Городское хозяйство         Иванов Петр Сергеевич
#
# [1736 rows x 12 columns]

# %% [markdown]
# Пятый пункт

# %%
df_main.groupby(by = ['Пол'])['Фамилия'].count().plot(kind = 'bar', grid= True)

# %%
df_main.groupby(by = ['Балл за тест'])['Фамилия'].count().plot()

# %%
df_main.groupby(by = ['Полных лет'])['Фамилия'].count().plot()

# %%
df_main.groupby(by = ['Роль'])['Фамилия'].count().plot(kind = 'bar', grid= True)
